# %%
import numpy as np
import pandas as pd
pd.set_option('use_inf_as_na', True)
import csv
from datetime import datetime
import re

# %%
# load in tweets data for training
path_to_file_2 = "Final datasets/users_tweets/"
df = pd.read_csv(path_to_file_2+"API_tweets_homelessness_for_features.csv")

# %%
# swear words prevalence
file = open("swearwords.txt","r")
swearwords = []
for line in file:
    swearwords.append(line)
swearwords = list(map(lambda each:each.strip("\n"), swearwords))

# %%
# polite/customer service phrases
file = open("customerservice.txt","r")
polite = []
for line in file:
    polite.append(line)
polite = list(map(lambda each:each.strip("\n"), polite))

# %%
# r/4chan negative sentiment phrases
file = open("4chan.txt","r")
chan = []
for line in file:
    if len(line) > 2:
        chan.append(line)
chan = list(map(lambda each:each.strip("\n"), chan))

# %%
# tokenise tweets

import preprocessor as p
from nltk.tokenize import word_tokenize
import string
from nltk.corpus import stopwords

df.text = df.text.astype(str)

punctuation = string.punctuation
other = '“¡…'
punctuation2 = punctuation + other
stop_words = stopwords.words('english')
    
tokens = []
cleaned = []

df['text'] = df['text'].str.casefold()

for i in df['text']:
    # clean drops items mentions, hasthags, hyperlinks, emojis etc
    clean = p.clean(i)
    # token seperates tweets into lists of words
    token = word_tokenize(clean)
    # words removes punctuated items, empty items and stopwords
    words = [''.join(c for c in s if c not in punctuation2) for s in token]
    words = [s for s in words if len(s) > 1]
    words = [w for w in words if not w in stop_words]
    sentence = ' '.join(word for word in words)
    tokens.append(words)
    cleaned.append(sentence)

df['tokens'] = tokens
df['text_clean'] = cleaned

# %%
# occurences per tweet of phrases
matches = []
for i in df.tokens:
    match = len(list(set(i) & set(swearwords)))
    matches.append(match)
df['swears'] = matches

matches2 = []
for i in df.tokens:
    match = len(list(set(i) & set(polite)))
    matches2.append(match)
df['polite'] = matches2

matches3 = []
for i in df.tokens:
    match = len(list(set(i) & set(chan)))
    matches3.append(match)
df['fourchan'] = matches3

df.tail()
# Out:
#          Unnamed: 0        date      time screen_name  \
# 2166231     2166265  2020-01-05  17:04:46  zyshanaryf
# 2166232     2166266  2020-01-05  17:04:15  zyshanaryf
# 2166233     2166267  2020-01-05  13:16:21  zyshanaryf
# 2166234     2166268  2020-01-05  01:13:31  zyshanaryf
# 2166235     2166269  2020-01-05  01:12:24  zyshanaryf
#
#                                                       text       tweetid  \
# 2166231  rt @aoc: this is a war crime.\n\nthreatening t...  1.213869e+18
# 2166232  rt @kaepernick7: there is nothing new about am...  1.213869e+18
# 2166233  texans. titans. saints. seahawks.\n\n2 of 4 so...  1.213811e+18
# 2166234  @nfluk @deshaunwatson this dude is a born winn...  1.213630e+18
# 2166235  rt @nfluk: speechless.\n\n@deshaunwatson... wo...  1.213629e+18
#
#                     datetime  retweet_count  favourite_count  \
# 2166231  2020-01-05 17:04:46        96615.0              0.0
# 2166232  2020-01-05 17:04:15        22924.0              0.0
# 2166233  2020-01-05 13:16:21            0.0              0.0
# 2166234  2020-01-05 01:13:31            0.0              0.0
# 2166235  2020-01-05 01:12:24          219.0              0.0
#
#                                                     tokens  \
# 2166231  [rt, war, crime, threatening, target, kill, in...
# 2166232  [rt, nothing, new, american, terrorist, attack...
# 2166233            [texans, titans, saints, seahawks, far]
# 2166234  [dude, born, winner, utterly, absurd, continua...
# 2166235                              [rt, speechless, wow]
#
#                                                 text_clean  swears
# 2166231  rt war crime threatening target kill innocent ...       0
# 2166232  rt nothing new american terrorist attacks blac...       0
# 2166233                  texans titans saints seahawks far       0
# 2166234  dude born winner utterly absurd continually wi...       0
# 2166235                                  rt speechless wow       0

# %%
# mean prevalence by users
users = df.groupby('screen_name').mean()
users = users.iloc[:,1:].copy()
users
# Out:
#                       tweetid  retweet_count  favourite_count    swears  \
# screen_name
# 008Mi7           1.244086e+18     214.785000         0.070000  0.005000
# 01iver5haw       1.238395e+18    3750.834171         0.758794  0.005025
# 02pash           1.249757e+18      10.490000         0.570000  0.015000
# 05_noodle        1.247299e+18    1164.792746         0.518135  0.077720
# 0644labella      1.250203e+18       0.010000         0.200000  0.015000
# ...                       ...            ...              ...       ...
# zuma_khulubuse   1.253582e+18     100.610000         2.210000  0.040000
# zumayabooks      1.254236e+18      37.025000         1.245000  0.015000
# zwideservesbass  1.254651e+18     210.685000         0.935000  0.085000
# zwitterion_work  1.253758e+18    2447.980000         0.140000  0.050000
# zyshanaryf       1.234646e+18    9252.899497         0.447236  0.417085
#
#                    polite  fourchan
# screen_name
# 008Mi7           0.080000  0.390000
# 01iver5haw       0.065327  0.311558
# 02pash           0.115000  0.205000
# 05_noodle        0.025907  0.165803
# 0644labella      0.185000  0.455000
# ...                   ...       ...
# zuma_khulubuse   0.055000  0.440000
# zumayabooks      0.080000  0.550000
# zwideservesbass  0.050000  0.220000
# zwitterion_work  0.075000  0.275000
# zyshanaryf       0.050251  0.361809
#
# [11274 rows x 6 columns]

# %%
# include log versions
log_swears,log_polite,log_fourchan  = users.swears.apply(np.log).fillna(0),users.polite.apply(np.log).fillna(0),users.fourchan.apply(np.log).fillna(0)
users['log_swears'],users['log_polite'],users['log_fourchan'] = log_swears,log_polite,log_fourchan
users
# Out:
#                       tweetid  retweet_count  favourite_count    swears  \
# screen_name
# 008Mi7           1.244086e+18     214.785000         0.070000  0.005000
# 01iver5haw       1.238395e+18    3750.834171         0.758794  0.005025
# 02pash           1.249757e+18      10.490000         0.570000  0.015000
# 05_noodle        1.247299e+18    1164.792746         0.518135  0.077720
# 0644labella      1.250203e+18       0.010000         0.200000  0.015000
# ...                       ...            ...              ...       ...
# zuma_khulubuse   1.253582e+18     100.610000         2.210000  0.040000
# zumayabooks      1.254236e+18      37.025000         1.245000  0.015000
# zwideservesbass  1.254651e+18     210.685000         0.935000  0.085000
# zwitterion_work  1.253758e+18    2447.980000         0.140000  0.050000
# zyshanaryf       1.234646e+18    9252.899497         0.447236  0.417085
#
#                    polite  fourchan  log_swears  log_polite  log_fourchan
# screen_name
# 008Mi7           0.080000  0.390000   -5.298317   -2.525729     -0.941609
# 01iver5haw       0.065327  0.311558   -5.293305   -2.728355     -1.166170
# 02pash           0.115000  0.205000   -4.199705   -2.162823     -1.584745
# 05_noodle        0.025907  0.165803   -2.554640   -3.653252     -1.796954
# 0644labella      0.185000  0.455000   -4.199705   -1.687399     -0.787458
# ...                   ...       ...         ...         ...           ...
# zuma_khulubuse   0.055000  0.440000   -3.218876   -2.900422     -0.820981
# zumayabooks      0.080000  0.550000   -4.199705   -2.525729     -0.597837
# zwideservesbass  0.050000  0.220000   -2.465104   -2.995732     -1.514128
# zwitterion_work  0.075000  0.275000   -2.995732   -2.590267     -1.290984
# zyshanaryf       0.050251  0.361809   -0.874464   -2.990720     -1.016639
#
# [11274 rows x 9 columns]

# %%
# tweets during office hours
screen_names = users.index.to_list()

# %%
gp = df.groupby('screen_name')['tweetid'].count()
gp.sort_values(0).tail(11)
# Out:
# screen_name
# FATbaddieonabu1    200
# TVTalkWithJWalk    200
# TTaesarang         200
# FBACOMMITTEE       200
# FBrownWilliams     200
# TSpeth5            200
# FCN2go             200
# TSARidgeMeadows    200
# TRVST_Poverty      200
# ExpertLink2019     200
# 008Mi7             200
# Name: tweetid, dtype: int64

# %%
# tweet frequency by office hours for popular timezones - UTC based
office_hours = []

for i in screen_names:
    
    # slice by username
    test = pd.DataFrame(df.loc[df.screen_name == i])
    test['time'] = pd.to_datetime(test.time, format='%H:%M:%S')
    test['hour'] = test['time'].dt.hour
    
    # pivot by date and hour of tweet
    table = pd.pivot_table(test, values=['tweetid'], index=['date'],
                        columns=['hour'], aggfunc='count',fill_value=0)
   
    # formatting
    table2 = table.reset_index()
    table2.columns = table2.columns.droplevel()
    table2.rename(columns={table2.columns[0]: "date" }, inplace = True)
    
    # UTC hours - but not much we can do with timezone...
    nine_to_five_utc = [9,10,11,12,13,14,15,16,17] # gmt UK
    nine_to_five_est = [5,6,7,8,9,10,11,12,13] # east coast US
    nine_to_five_pct = [2,3,4,5,6,7,8,9,10] # west coast US
    nine_to_five_mst = [12,13,14,15,16,17,18,19,20]# Moscow standard
    nine_to_five_aus = [19,20,21,22,23,0,1,2,3] # australia east coast    
    
    # sum the amount of tweets between hours 9-5
    total = np.array(np.sum(table2.iloc[:,1:],axis=1))
    office_utc = np.array(np.sum(table2.reindex(columns = nine_to_five_utc, fill_value=0),axis=1))
    office_est = np.array(np.sum(table2.reindex(columns = nine_to_five_est, fill_value=0),axis=1))
    office_pct = np.array(np.sum(table2.reindex(columns = nine_to_five_pct, fill_value=0),axis=1))
    office_mst = np.array(np.sum(table2.reindex(columns = nine_to_five_mst, fill_value=0),axis=1))
    office_aus = np.array(np.sum(table2.reindex(columns = nine_to_five_aus, fill_value=0),axis=1))

    # return the percentage for each day and take average - can do either way..
    timezones =  [office_utc,office_est, office_pct,office_mst,office_aus]
    means = []
    
    for i in timezones:       
        mean_hours = np.round((np.sum(i)/np.sum(total)),decimals=3)
        means.append(mean_hours)
        
    office_hours.append(means)

office_hours_df = pd.DataFrame(office_hours,columns=['utc','est','pct','mst','aus'])
office_hours_df['username'] = screen_names
office_hours_df = office_hours_df[['username','utc','est','pct','mst','aus']]

# %%
office_hours_df.columns = ['username','office_hours_utc','office_hours_est',
                           'office_hours_pct','office_hours_mst','office_hours_aus']

office_hours_df

# %%
accounts_train = accounts_train.merge(users,how='left',left_on='username',right_on=users.index)
accounts_train = accounts_train.drop(columns=['tweetid','retweet_count','favourite_count'])

# %%
accounts_train = accounts_train.merge(office_hours_df,how='left',left_on='username',right_on='username')
accounts_train.head()
# Out:
#                     id                                               name  \
# 0  1238173275743805440  0008MI:8 REDBULL CODENAME TARSOC | ANCIENT 1 O...
# 1  1113034041408806912                                           oliver s
# 2            753578136                                         Niall Love
# 3  1041061771723907072                                               Fish
# 4            249481775                                                 Da
#
#       username                  location                      url  \
# 0       008Mi7  Kington Langley, England  https://t.co/XkOZohK2d3
# 1   01iver5haw           United Kingdom   https://t.co/UaeTsGvWJQ
# 2       02pash                       NaN                      NaN
# 3    05_noodle                he/him!!!!                      NaN
# 4  0644labella                       NaN                      NaN
#
#                                          description  verified  followers  \
# 0  I'm a blown cover agent protecting World secur...     False         22
# 1                       history @ oxford • midlander     False         73
# 2  To  fight and support for the rights of the ho...     False        362
# 3  Kyle is everything Harry Potter wishes he was ...     False         55
# 4                                                NaN     False         13
#
#    friends  favourites_count  ...    polite  fourchan  log_swears log_polite  \
# 0      722               175  ...  0.080000  0.390000   -5.298317  -2.525729
# 1      327              2940  ...  0.065327  0.311558   -5.293305  -2.728355
# 2      288              7928  ...  0.115000  0.205000   -4.199705  -2.162823
# 3      193             27565  ...  0.025907  0.165803   -2.554640  -3.653252
# 4       78              1191  ...  0.185000  0.455000   -4.199705  -1.687399
#
#    log_fourchan  office_hours_utc  office_hours_est  office_hours_pct  \
# 0     -0.941609             0.535             0.165             0.195
# 1     -1.166170             0.462             0.251             0.111
# 2     -1.584745             0.615             0.605             0.385
# 3     -1.796954             0.057             0.161             0.363
# 4     -0.787458             0.245             0.020             0.070
#
#    office_hours_mst  office_hours_aus
# 0             0.645             0.330
# 1             0.558             0.427
# 2             0.550             0.095
# 3             0.228             0.637
# 4             0.515             0.685
#
# [5 rows x 42 columns]

# %%
# save as csv

# %%
accounts_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 0 to 11352
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              11353 non-null  int64
#  1   name                            11352 non-null  object
#  2   username                        11353 non-null  object
#  3   location                        8578 non-null   object
#  4   url                             4814 non-null   object
#  5   description                     10198 non-null  object
#  6   verified                        11353 non-null  bool
#  7   followers                       11353 non-null  int64
#  8   friends                         11353 non-null  int64
#  9   favourites_count                11353 non-null  int64
#  10  statuses_count                  11353 non-null  int64
#  11  default_profile                 11353 non-null  int64
#  12  default_profile_image           11353 non-null  int64
#  13  date_created                    11353 non-null  object
#  14  days_active                     11353 non-null  int64
#  15  followers_age                   11353 non-null  float64
#  16  following_age                   11353 non-null  float64
#  17  favourites_age                  11353 non-null  float64
#  18  tweets_age                      11353 non-null  float64
#  19  followers_ratio                 11261 non-null  float64
#  20  username_char_len               11353 non-null  int64
#  21  name_ratio                      11353 non-null  float64
#  22  username_int                    11353 non-null  int64
#  23  username_char                   11353 non-null  int64
#  24  username_other                  11353 non-null  int64
#  25  username_int_end                11353 non-null  int64
#  26  name_int                        11353 non-null  int64
#  27  non_unique_tweets               11274 non-null  float64
#  28  average_tweets_day              11274 non-null  float64
#  29  average_minutes_between_tweets  11267 non-null  float64
#  30  average_hours_tweeted           11274 non-null  float64
#  31  swears                          11274 non-null  float64
#  32  polite                          11274 non-null  float64
#  33  fourchan                        11274 non-null  float64
#  34  log_swears                      11274 non-null  float64
#  35  log_polite                      11274 non-null  float64
#  36  log_fourchan                    11274 non-null  float64
#  37  office_hours_utc                11274 non-null  float64
#  38  office_hours_est                11274 non-null  float64
#  39  office_hours_pct                11274 non-null  float64
#  40  office_hours_mst                11274 non-null  float64
#  41  office_hours_aus                11274 non-null  float64
# dtypes: bool(1), float64(21), int64(14), object(6)
# memory usage: 3.6+ MB

# %%
# load in datasets and merge with new data

# %%
stefan_training = pd.read_csv("Final datasets/content_data/homelessness.csv")
training = accounts_train
stefan_training.shape
# Out:
# (11274, 37)

# %%
training = training.merge(stefan_training,how="left",left_on="username",right_on="screen_name")

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 0 to 11352
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              11353 non-null  int64
#  1   name                            11352 non-null  object
#  2   username                        11353 non-null  object
#  3   location                        8578 non-null   object
#  4   url                             4814 non-null   object
#  5   description                     10198 non-null  object
#  6   verified                        11353 non-null  bool
#  7   followers                       11353 non-null  int64
#  8   friends                         11353 non-null  int64
#  9   favourites_count                11353 non-null  int64
#  10  statuses_count                  11353 non-null  int64
#  11  default_profile                 11353 non-null  int64
#  12  default_profile_image           11353 non-null  int64
#  13  date_created                    11353 non-null  object
#  14  days_active                     11353 non-null  int64
#  15  followers_age                   11353 non-null  float64
#  16  following_age                   11353 non-null  float64
#  17  favourites_age                  11353 non-null  float64
#  18  tweets_age                      11353 non-null  float64
#  19  followers_ratio                 11261 non-null  float64
#  20  username_char_len               11353 non-null  int64
#  21  name_ratio                      11353 non-null  float64
#  22  username_int                    11353 non-null  int64
#  23  username_char                   11353 non-null  int64
#  24  username_other                  11353 non-null  int64
#  25  username_int_end                11353 non-null  int64
#  26  name_int                        11353 non-null  int64
#  27  non_unique_tweets               11274 non-null  float64
#  28  average_tweets_day              11274 non-null  float64
#  29  average_minutes_between_tweets  11267 non-null  float64
#  30  average_hours_tweeted           11274 non-null  float64
#  31  swears                          11274 non-null  float64
#  32  polite                          11274 non-null  float64
#  33  fourchan                        11274 non-null  float64
#  34  log_swears                      11274 non-null  float64
#  35  log_polite                      11274 non-null  float64
#  36  log_fourchan                    11274 non-null  float64
#  37  office_hours_utc                11274 non-null  float64
#  38  office_hours_est                11274 non-null  float64
#  39  office_hours_pct                11274 non-null  float64
#  40  office_hours_mst                11274 non-null  float64
#  41  office_hours_aus                11274 non-null  float64
#  42  screen_name                     11274 non-null  object
#  43  tot_tweets                      11274 non-null  float64
#  44  retweets                        11274 non-null  float64
#  45  ogtweets                        11274 non-null  float64
#  46  retweet_countOT                 11274 non-null  float64
#  47  favourite_countOT               11274 non-null  float64
#  48  OGTratio                        11274 non-null  float64
#  49  char_OT                         11274 non-null  float64
#  50  ment_OT                         11274 non-null  float64
#  51  w/urlR_OT                       11274 non-null  float64
#  52  sent_OT                         11274 non-null  float64
#  53  words_OT                        11274 non-null  float64
#  54  alp_OT                          11274 non-null  float64
#  55  cap_OT                          11274 non-null  float64
#  56  capR_OT                         11274 non-null  float64
#  57  TCW_OT                          11274 non-null  float64
#  58  TSW_OT                          11274 non-null  float64
#  59  nHW_OT                          11274 non-null  float64
#  60  StopW_OT                        11274 non-null  float64
#  61  nouns_OT                        11274 non-null  float64
#  62  adj_OT                          11274 non-null  float64
#  63  verbs_OT                        11274 non-null  float64
#  64  adv_OT                          11274 non-null  float64
#  65  pron_OT                         11274 non-null  float64
#  66  Tot_entities_OT                 11274 non-null  float64
#  67  People_OT                       11274 non-null  float64
#  68  ORGs_OT                         11274 non-null  float64
#  69  pHW_OT                          11274 non-null  float64
#  70  pStopW_OT                       11274 non-null  float64
#  71  pnouns_OT                       11274 non-null  float64
#  72  padj_OT                         11274 non-null  float64
#  73  pverbs_OT                       11274 non-null  float64
#  74  padv_OT                         11274 non-null  float64
#  75  ppron_OT                        11274 non-null  float64
#  76  Gun_Index                       11274 non-null  float64
#  77  tot_hashtags                    11274 non-null  float64
#  78  hash_PT                         11274 non-null  float64
# dtypes: bool(1), float64(57), int64(14), object(7)
# memory usage: 6.9+ MB

# %%
training = training.drop(columns='screen_name')

# %%
aris_climate = pd.read_csv("Final datasets/business_specific/business_users_homelessness.csv")
aris_climate
# Out:
#        Unnamed: 0                   id         username  \
# 0               0  1238173275743805440           008Mi7
# 1               1  1113034041408806912       01iver5haw
# 2               2            753578136           02pash
# 3               3  1041061771723907072        05_noodle
# 4               4            249481775      0644labella
# ...           ...                  ...              ...
# 11348       11348  1192842602086895617   zuma_khulubuse
# 11349       11349             14948080      zumayabooks
# 11350       11350            216353292  zwideservesbass
# 11351       11351             44130732  zwitterion_work
# 11352       11352            280038595       zyshanaryf
#
#                                               url_titles  \
# 0                               National Security Agency
# 1      oliver shaw. – blog. couldn't think of a bette...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11348                                                NaN
# 11349  Liz Burton's Portable Soup | “We live not for ...
# 11350  Better Late EP by Zwide Ndwandwe | Free Listen...
# 11351                                               None
# 11352                                                NaN
#
#        username_urltitle_simimlarity username_in_urltitle  \
# 0                           0.066667                False
# 1                           0.225806                False
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
# ...                              ...                  ...
# 11348                            NaN                  NaN
# 11349                       0.119205                False
# 11350                       0.205128                False
# 11351                       0.222222                False
# 11352                            NaN                  NaN
#
#        username_name_similarity  username_in_bio  lower_userid  \
# 0                      0.178571            False         False
# 1                      0.444444            False         False
# 2                      0.125000            False          True
# 3                      0.000000            False         False
# 4                      0.153846            False          True
# ...                         ...              ...           ...
# 11348                  0.692308            False         False
# 11349                  0.109091            False          True
# 11350                  0.903226            False          True
# 11351                  0.277778            False          True
# 11352                  0.952381            False          True
#
#        followers_friends_ratio bio_sentiment
# 0                     0.030471      negative
# 1                     0.223242       neutral
# 2                     1.256944      negative
# 3                     0.284974       neutral
# 4                     0.166667       neutral
# ...                        ...           ...
# 11348                20.327485       neutral
# 11349                 0.866990      negative
# 11350                 1.451482      positive
# 11351                 0.686211       neutral
# 11352                 1.865385      positive
#
# [11353 rows x 11 columns]

# %%
aris_climate = aris_climate.iloc[:,1:]
aris_climate
# Out:
#                         id         username  \
# 0      1238173275743805440           008Mi7
# 1      1113034041408806912       01iver5haw
# 2                753578136           02pash
# 3      1041061771723907072        05_noodle
# 4                249481775      0644labella
# ...                    ...              ...
# 11348  1192842602086895617   zuma_khulubuse
# 11349             14948080      zumayabooks
# 11350            216353292  zwideservesbass
# 11351             44130732  zwitterion_work
# 11352            280038595       zyshanaryf
#
#                                               url_titles  \
# 0                               National Security Agency
# 1      oliver shaw. – blog. couldn't think of a bette...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11348                                                NaN
# 11349  Liz Burton's Portable Soup | “We live not for ...
# 11350  Better Late EP by Zwide Ndwandwe | Free Listen...
# 11351                                               None
# 11352                                                NaN
#
#        username_urltitle_simimlarity username_in_urltitle  \
# 0                           0.066667                False
# 1                           0.225806                False
# 2                                NaN                  NaN
# 3                                NaN                  NaN
# 4                                NaN                  NaN
# ...                              ...                  ...
# 11348                            NaN                  NaN
# 11349                       0.119205                False
# 11350                       0.205128                False
# 11351                       0.222222                False
# 11352                            NaN                  NaN
#
#        username_name_similarity  username_in_bio  lower_userid  \
# 0                      0.178571            False         False
# 1                      0.444444            False         False
# 2                      0.125000            False          True
# 3                      0.000000            False         False
# 4                      0.153846            False          True
# ...                         ...              ...           ...
# 11348                  0.692308            False         False
# 11349                  0.109091            False          True
# 11350                  0.903226            False          True
# 11351                  0.277778            False          True
# 11352                  0.952381            False          True
#
#        followers_friends_ratio bio_sentiment
# 0                     0.030471      negative
# 1                     0.223242       neutral
# 2                     1.256944      negative
# 3                     0.284974       neutral
# 4                     0.166667       neutral
# ...                        ...           ...
# 11348                20.327485       neutral
# 11349                 0.866990      negative
# 11350                 1.451482      positive
# 11351                 0.686211       neutral
# 11352                 1.865385      positive
#
# [11353 rows x 10 columns]

# %%
training = training.merge(aris_climate,how='left',left_on='id',right_on='id')

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 0 to 11352
# Data columns (total 87 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              11353 non-null  int64
#  1   name                            11352 non-null  object
#  2   username_x                      11353 non-null  object
#  3   location                        8578 non-null   object
#  4   url                             4814 non-null   object
#  5   description                     10198 non-null  object
#  6   verified                        11353 non-null  bool
#  7   followers                       11353 non-null  int64
#  8   friends                         11353 non-null  int64
#  9   favourites_count                11353 non-null  int64
#  10  statuses_count                  11353 non-null  int64
#  11  default_profile                 11353 non-null  int64
#  12  default_profile_image           11353 non-null  int64
#  13  date_created                    11353 non-null  object
#  14  days_active                     11353 non-null  int64
#  15  followers_age                   11353 non-null  float64
#  16  following_age                   11353 non-null  float64
#  17  favourites_age                  11353 non-null  float64
#  18  tweets_age                      11353 non-null  float64
#  19  followers_ratio                 11261 non-null  float64
#  20  username_char_len               11353 non-null  int64
#  21  name_ratio                      11353 non-null  float64
#  22  username_int                    11353 non-null  int64
#  23  username_char                   11353 non-null  int64
#  24  username_other                  11353 non-null  int64
#  25  username_int_end                11353 non-null  int64
#  26  name_int                        11353 non-null  int64
#  27  non_unique_tweets               11274 non-null  float64
#  28  average_tweets_day              11274 non-null  float64
#  29  average_minutes_between_tweets  11267 non-null  float64
#  30  average_hours_tweeted           11274 non-null  float64
#  31  swears                          11274 non-null  float64
#  32  polite                          11274 non-null  float64
#  33  fourchan                        11274 non-null  float64
#  34  log_swears                      11274 non-null  float64
#  35  log_polite                      11274 non-null  float64
#  36  log_fourchan                    11274 non-null  float64
#  37  office_hours_utc                11274 non-null  float64
#  38  office_hours_est                11274 non-null  float64
#  39  office_hours_pct                11274 non-null  float64
#  40  office_hours_mst                11274 non-null  float64
#  41  office_hours_aus                11274 non-null  float64
#  42  tot_tweets                      11274 non-null  float64
#  43  retweets                        11274 non-null  float64
#  44  ogtweets                        11274 non-null  float64
#  45  retweet_countOT                 11274 non-null  float64
#  46  favourite_countOT               11274 non-null  float64
#  47  OGTratio                        11274 non-null  float64
#  48  char_OT                         11274 non-null  float64
#  49  ment_OT                         11274 non-null  float64
#  50  w/urlR_OT                       11274 non-null  float64
#  51  sent_OT                         11274 non-null  float64
#  52  words_OT                        11274 non-null  float64
#  53  alp_OT                          11274 non-null  float64
#  54  cap_OT                          11274 non-null  float64
#  55  capR_OT                         11274 non-null  float64
#  56  TCW_OT                          11274 non-null  float64
#  57  TSW_OT                          11274 non-null  float64
#  58  nHW_OT                          11274 non-null  float64
#  59  StopW_OT                        11274 non-null  float64
#  60  nouns_OT                        11274 non-null  float64
#  61  adj_OT                          11274 non-null  float64
#  62  verbs_OT                        11274 non-null  float64
#  63  adv_OT                          11274 non-null  float64
#  64  pron_OT                         11274 non-null  float64
#  65  Tot_entities_OT                 11274 non-null  float64
#  66  People_OT                       11274 non-null  float64
#  67  ORGs_OT                         11274 non-null  float64
#  68  pHW_OT                          11274 non-null  float64
#  69  pStopW_OT                       11274 non-null  float64
#  70  pnouns_OT                       11274 non-null  float64
#  71  padj_OT                         11274 non-null  float64
#  72  pverbs_OT                       11274 non-null  float64
#  73  padv_OT                         11274 non-null  float64
#  74  ppron_OT                        11274 non-null  float64
#  75  Gun_Index                       11274 non-null  float64
#  76  tot_hashtags                    11274 non-null  float64
#  77  hash_PT                         11274 non-null  float64
#  78  username_y                      11353 non-null  object
#  79  url_titles                      4781 non-null   object
#  80  username_urltitle_simimlarity   4403 non-null   float64
#  81  username_in_urltitle            4403 non-null   object
#  82  username_name_similarity        11353 non-null  float64
#  83  username_in_bio                 11353 non-null  bool
#  84  lower_userid                    11353 non-null  bool
#  85  followers_friends_ratio         11294 non-null  float64
#  86  bio_sentiment                   11353 non-null  object
# dtypes: bool(3), float64(60), int64(14), object(10)
# memory usage: 7.4+ MB

# %%
training = training.drop(columns='followers_ratio')

# %%
training.username_in_urltitle = training.username_in_urltitle*1
training.username_in_bio = training.username_in_bio*1
training.lower_userid = training.lower_userid*1
training.head()
# Out:
#                     id                                               name  \
# 0  1238173275743805440  0008MI:8 REDBULL CODENAME TARSOC | ANCIENT 1 O...
# 1  1113034041408806912                                           oliver s
# 2            753578136                                         Niall Love
# 3  1041061771723907072                                               Fish
# 4            249481775                                                 Da
#
#     username_x                  location                      url  \
# 0       008Mi7  Kington Langley, England  https://t.co/XkOZohK2d3
# 1   01iver5haw           United Kingdom   https://t.co/UaeTsGvWJQ
# 2       02pash                       NaN                      NaN
# 3    05_noodle                he/him!!!!                      NaN
# 4  0644labella                       NaN                      NaN
#
#                                          description  verified  followers  \
# 0  I'm a blown cover agent protecting World secur...     False         22
# 1                       history @ oxford • midlander     False         73
# 2  To  fight and support for the rights of the ho...     False        362
# 3  Kyle is everything Harry Potter wishes he was ...     False         55
# 4                                                NaN     False         13
#
#    friends  favourites_count  ...   hash_PT   username_y  \
# 0      722               175  ...  0.250000       008Mi7
# 1      327              2940  ...  0.125628   01iver5haw
# 2      288              7928  ...  0.335000       02pash
# 3      193             27565  ...  0.145078    05_noodle
# 4       78              1191  ...  0.000000  0644labella
#
#                                           url_titles  \
# 0                           National Security Agency
# 1  oliver shaw. – blog. couldn't think of a bette...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   username_urltitle_simimlarity  username_in_urltitle  \
# 0                      0.066667                     0
# 1                      0.225806                     0
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
#
#    username_name_similarity  username_in_bio  lower_userid  \
# 0                  0.178571                0             0
# 1                  0.444444                0             0
# 2                  0.125000                0             1
# 3                  0.000000                0             0
# 4                  0.153846                0             1
#
#    followers_friends_ratio  bio_sentiment
# 0                 0.030471       negative
# 1                 0.223242        neutral
# 2                 1.256944       negative
# 3                 0.284974        neutral
# 4                 0.166667        neutral
#
# [5 rows x 86 columns]

# %%
training = pd.get_dummies(training, columns=['bio_sentiment'])

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11353 entries, 0 to 11352
# Data columns (total 88 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              11353 non-null  int64
#  1   name                            11352 non-null  object
#  2   username_x                      11353 non-null  object
#  3   location                        8578 non-null   object
#  4   url                             4814 non-null   object
#  5   description                     10198 non-null  object
#  6   verified                        11353 non-null  bool
#  7   followers                       11353 non-null  int64
#  8   friends                         11353 non-null  int64
#  9   favourites_count                11353 non-null  int64
#  10  statuses_count                  11353 non-null  int64
#  11  default_profile                 11353 non-null  int64
#  12  default_profile_image           11353 non-null  int64
#  13  date_created                    11353 non-null  object
#  14  days_active                     11353 non-null  int64
#  15  followers_age                   11353 non-null  float64
#  16  following_age                   11353 non-null  float64
#  17  favourites_age                  11353 non-null  float64
#  18  tweets_age                      11353 non-null  float64
#  19  username_char_len               11353 non-null  int64
#  20  name_ratio                      11353 non-null  float64
#  21  username_int                    11353 non-null  int64
#  22  username_char                   11353 non-null  int64
#  23  username_other                  11353 non-null  int64
#  24  username_int_end                11353 non-null  int64
#  25  name_int                        11353 non-null  int64
#  26  non_unique_tweets               11274 non-null  float64
#  27  average_tweets_day              11274 non-null  float64
#  28  average_minutes_between_tweets  11267 non-null  float64
#  29  average_hours_tweeted           11274 non-null  float64
#  30  swears                          11274 non-null  float64
#  31  polite                          11274 non-null  float64
#  32  fourchan                        11274 non-null  float64
#  33  log_swears                      11274 non-null  float64
#  34  log_polite                      11274 non-null  float64
#  35  log_fourchan                    11274 non-null  float64
#  36  office_hours_utc                11274 non-null  float64
#  37  office_hours_est                11274 non-null  float64
#  38  office_hours_pct                11274 non-null  float64
#  39  office_hours_mst                11274 non-null  float64
#  40  office_hours_aus                11274 non-null  float64
#  41  tot_tweets                      11274 non-null  float64
#  42  retweets                        11274 non-null  float64
#  43  ogtweets                        11274 non-null  float64
#  44  retweet_countOT                 11274 non-null  float64
#  45  favourite_countOT               11274 non-null  float64
#  46  OGTratio                        11274 non-null  float64
#  47  char_OT                         11274 non-null  float64
#  48  ment_OT                         11274 non-null  float64
#  49  w/urlR_OT                       11274 non-null  float64
#  50  sent_OT                         11274 non-null  float64
#  51  words_OT                        11274 non-null  float64
#  52  alp_OT                          11274 non-null  float64
#  53  cap_OT                          11274 non-null  float64
#  54  capR_OT                         11274 non-null  float64
#  55  TCW_OT                          11274 non-null  float64
#  56  TSW_OT                          11274 non-null  float64
#  57  nHW_OT                          11274 non-null  float64
#  58  StopW_OT                        11274 non-null  float64
#  59  nouns_OT                        11274 non-null  float64
#  60  adj_OT                          11274 non-null  float64
#  61  verbs_OT                        11274 non-null  float64
#  62  adv_OT                          11274 non-null  float64
#  63  pron_OT                         11274 non-null  float64
#  64  Tot_entities_OT                 11274 non-null  float64
#  65  People_OT                       11274 non-null  float64
#  66  ORGs_OT                         11274 non-null  float64
#  67  pHW_OT                          11274 non-null  float64
#  68  pStopW_OT                       11274 non-null  float64
#  69  pnouns_OT                       11274 non-null  float64
#  70  padj_OT                         11274 non-null  float64
#  71  pverbs_OT                       11274 non-null  float64
#  72  padv_OT                         11274 non-null  float64
#  73  ppron_OT                        11274 non-null  float64
#  74  Gun_Index                       11274 non-null  float64
#  75  tot_hashtags                    11274 non-null  float64
#  76  hash_PT                         11274 non-null  float64
#  77  username_y                      11353 non-null  object
#  78  url_titles                      4781 non-null   object
#  79  username_urltitle_simimlarity   4403 non-null   float64
#  80  username_in_urltitle            4403 non-null   object
#  81  username_name_similarity        11353 non-null  float64
#  82  username_in_bio                 11353 non-null  int64
#  83  lower_userid                    11353 non-null  int64
#  84  followers_friends_ratio         11294 non-null  float64
#  85  bio_sentiment_negative          11353 non-null  uint8
#  86  bio_sentiment_neutral           11353 non-null  uint8
#  87  bio_sentiment_positive          11353 non-null  uint8
# dtypes: bool(1), float64(59), int64(16), object(9), uint8(3)
# memory usage: 7.4+ MB

# %%
training = training.drop(columns='url_titles')

# %%
training2.to_csv("homelessness_users_features.csv")

# %%
training2 = training.dropna(subset=['id'])
training2.shape
# Out:
# (11353, 87)
